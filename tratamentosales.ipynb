# %%
import pandas as pd
from sqlalchemy import create_engine
df = pd.read_csv(r"F:\projetos dados\e-commerce\E-commerece sales data 2024.csv")
df2 = pd.read_csv(r"F:\projetos dados\e-commerce\E-commerece sales data 2024.csv")

# %%
dfproducts = pd.read_excel(r"F:\projetos dados\e-commerce\Dados Tratados\Detalhes de produtos.xlsx")

# %%
df.drop("Unnamed: 4", axis= 1,inplace=True)

# %%
df.isnull().sum()
# Out:
# user id             295
# product id          295
# Interaction type    423
# Time stamp          295
# dtype: int64

# %%
df = df[(df["product id"].notnull()) & (df["user id"].notnull()) | 
        ((df["product id"].isnull()) & (df["user id"].isnull()) & (df["Interaction type"] == "purchase"))]

df ["product id"].fillna("desconhecido")
df ["user id"].fillna("desconhecido")
df ["Interaction type"] = df["Interaction type"].fillna("Desconhecido")
print(df.isnull().sum())
# Out:
# user id             0
# product id          0
# Interaction type    0
# Time stamp          0
# dtype: int64

# %%
df["user id"] = df ["user id"].astype(int)

# %%
df ["Time stamp"] = pd.to_datetime(df["Time stamp"], dayfirst=True)

# %%
engine = create_engine ("postgresql://postgres:Lf19092019f-@localhost:5432/Python")
df.to_sql("vendas_2024", engine, if_exists="replace", index=False)
# Out:
# 999

# %%
pasta_destino = r"F:\\projetos dados\\e-commerce\\Dados Tratados\\"
caminho_arquivo = r"vendas_2024.xlsx"
caminho_completo = pasta_destino + caminho_arquivo


df.to_excel (caminho_completo, index=False)

# %%
df = df.loc [df["Interaction type"] == "purchase"]
df
# Out:
#       user id                        product id Interaction type  \
# 0           1  4c69b61db1fc16e7013b43fc926e502d         purchase
# 6           7  40d3cd16b41970ae6872e914aecf2c8e         purchase
# 9          10  69828c5570dcdbd1609216d33fbad0db         purchase
# 10         11  7b0746d8afc8462ba17f8a763d9d5f1e         purchase
# 16         17  d82015ffbf4cd54b0edfb890002971f3         purchase
# ...       ...                               ...              ...
# 2982     2983  fdb871290f16fa018ffc6abf04630696         purchase
# 2988     2989  06e8480f75c0414c5b0441e6df159f35         purchase
# 2991     2992  2e26df8b0c3338d980ffa909786e0d2b         purchase
# 2992     2993  f1c169fc0fbc069fdb894309f5a26d3a         purchase
# 2996     2997  19d150365d798db47cccf1622b6ad754         purchase
#
#               Time stamp
# 0    2023-10-10 08:00:00
# 6    2023-10-16 08:00:00
# 9    2023-10-19 08:00:00
# 10   2023-10-20 08:00:00
# 16   2023-10-26 08:00:00
# ...                  ...
# ...

# %%
dfproducts ["Preco de venda"] = dfproducts ["Preco de venda"].str.replace ("[$, ,]","", regex=True)

# %%
dfproducts ["Preco de venda"] = dfproducts ["Preco de venda"].astype(float)

# %%
vendidosIndice = []
for i in df["product id"]:
    for i2 in dfproducts ["Id unico"]:
        if i == i2:
            vendidosIndice.append(i2)

# %%
dfvendidos = dfproducts [dfproducts ["Id unico"].isin(vendidosIndice)]
dfvendidos.reset_index (drop=True)
dfvendidos_nao_listados = df [~df ["product id"].isin (dfvendidos ["Id unico"])]
dfvendidos_listados = df [df ["product id"].isin (dfvendidos ["Id unico"])]
print(len(dfvendidos["Preco de venda"]))
# Out:
# 825

# %%
contagemInteractions = df2["Interaction type"].value_counts()
like_count = (df2["Interaction type"] == "like").sum()
purchase_count = (df2["Interaction type"] == "purchase").sum()
view_count = (df2["Interaction type"] == "view").sum()

dfInteractions = pd.DataFrame(contagemInteractions)

# %%
dados = {
    "Interactions Types": ["purchase", "view", "like"],
    "Count": [purchase_count,view_count, like_count]
}

# %%
dados = pd.DataFrame(dados)
dfInteractions = dados

# %%
dfvendidos_nao_listados.reset_index(drop=True)
# Out:
#     user id                        product id Interaction type  \
# 0        40  c3296d8ad42c3998c205f0dbca3998f3         purchase
# 1       167  44af50aecebcfbca03654d2ab92aac6b         purchase
# 2       174  5ec9d590a90fce754b08cc415627ef07         purchase
# 3       195  39887c2739efaea41c8ff64b2bcf5a05         purchase
# 4       226  a6737b0c04b96b728bc14669376d3ebf         purchase
# 5       287  35d0e484bbb4687112e52071376dde6b         purchase
# 6       317  0b9df9bc7f554b556776ce0cf62debfa         purchase
# 7       324  89d180e819d5a779ddec1f8737488821         purchase
# 8       405  b895173a5ad0ec3f370777cf0953b52e         purchase
# 9       837  2864cd7f67cb38786b9075dac75095f9         purchase
# 10     1542  cd750dd8a8dbe8ce4a6376df6dcfcd6a         purchase
# 11     1557  058b419304a444bd5d68f3299506e92e         purchase
# 12     1645  d32d16992d9ffb3057780ed4b109260f         purchase
# 13     1656  326e3f0d49ec0a29045fec8d824d5caf         purchase
# ...

# %%
dfvendidos_nao_listados = (len(dfvendidos_nao_listados))

# %%
contagem_nao_listados = {"Vendidos_sem_Registros" : [dfvendidos_nao_listados]}

# %%
contagem_vendas = {"Vendas": [len(dfvendidos_listados)]}
dfcontagem_vendas = pd.DataFrame(contagem_vendas)

# %%
df_nao_listados = pd.DataFrame(contagem_nao_listados)

# %%
engine = create_engine("postgresql://postgres:Lf19092019f-@localhost:5432/Python",)

df_nao_listados.to_sql("vendidos_nao_registrados",engine, if_exists="replace", index=False)
dfcontagem_vendas.to_sql("contagem de vendas",engine,if_exists="replace",index=False)
dfvendidos.to_sql("vendidos_registrados",engine,if_exists="replace",index=False)
dfInteractions.to_sql("interacoes_tipos", engine, if_exists="replace",index=False)
# Out:
# 3
